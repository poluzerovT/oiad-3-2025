# %% [markdown]
# # Лабораторная работа №3

# %%
# !pip install kagglehub

import kagglehub

path = kagglehub.dataset_download("mosapabdelghany/medical-insurance-cost-dataset")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (0.3.13)
# Requirement already satisfied: packaging in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/n3vajnokto/pyenv/oiad/lib/python3.13/site-packages (from requests->kagglehub) (2025.10.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Path to dataset files: /home/n3vajnokto/.cache/kagglehub/datasets/mosapabdelghany/medical-insurance-cost-dataset/versions/1

# %%
import pandas as pd

data = pd.read_csv(f"{path}/insurance.csv")

data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Подготовка данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
num_columns = ["age", "bmi", "children", "charges"]
categorial_columns = list(set(data.columns) - set(num_columns))
print("численные:", num_columns)
print("категориальные:", categorial_columns)
print(data.shape)
data = data[(data[num_columns] - data[num_columns].mean() <= 3 * data[num_columns].std()).all(axis=1)]
print(data.shape)
data
# Out:
# численные: ['age', 'bmi', 'children', 'charges']
# категориальные: ['smoker', 'region', 'sex']
# (1338, 7)
# (1309, 7)
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1309 rows x 7 columns]

# %%
data = pd.get_dummies(data, columns=categorial_columns, drop_first=True)
data
# Out:
#       age     bmi  children      charges  smoker_yes  region_northwest  \
# 0      19  27.900         0  16884.92400        True             False
# 1      18  33.770         1   1725.55230       False             False
# 2      28  33.000         3   4449.46200       False             False
# 3      33  22.705         0  21984.47061       False              True
# 4      32  28.880         0   3866.85520       False              True
# ...   ...     ...       ...          ...         ...               ...
# 1333   50  30.970         3  10600.54830       False              True
# 1334   18  31.920         0   2205.98080       False             False
# 1335   18  36.850         0   1629.83350       False             False
# 1336   21  25.800         0   2007.94500       False             False
# 1337   61  29.070         0  29141.36030        True              True
#
#       region_southeast  region_southwest  sex_male
# 0                False              True     False
# 1                 True             False      True
# 2                 True             False      True
# 3                False             False      True
# 4                False             False      True
# ...                ...               ...       ...
# 1333             False             False      True
# 1334             False             False     False
# 1335              True             False     False
# 1336             False              True     False
# 1337             False             False     False
#
# [1309 rows x 9 columns]

# %%
data.corr()
# Out:
#                        age       bmi  children   charges  smoker_yes  \
# age               1.000000  0.118178  0.059100  0.305263   -0.029090
# bmi               0.118178  1.000000  0.029916  0.191453   -0.005288
# children          0.059100  0.029916  1.000000  0.100438    0.028844
# charges           0.305263  0.191453  0.100438  1.000000    0.785129
# smoker_yes       -0.029090 -0.005288  0.028844  0.785129    1.000000
# region_northwest -0.003449 -0.134342  0.044948 -0.045847   -0.040557
# region_southeast -0.014346  0.261014 -0.027381  0.074829    0.071776
# region_southwest  0.013766  0.002552  0.001275 -0.042922   -0.039005
# sex_male         -0.019253  0.042498  0.014056  0.059455    0.079058
#
#                   region_northwest  region_southeast  region_southwest  \
# age                      -0.003449         -0.014346          0.013766
# bmi                      -0.134342          0.261014          0.002552
# children                  0.044948         -0.027381          0.001275
# charges                  -0.045847          0.074829         -0.042922
# smoker_yes               -0.040557          0.071776         -0.039005
# region_northwest          1.000000         -0.346405         -0.321537
# region_southeast         -0.346405          1.000000         -0.341411
# region_southwest         -0.321537         -0.341411          1.000000
# sex_male                 -0.006602          0.013987         -0.004798
#
#                   sex_male
# age              -0.019253
# bmi               0.042498
# children          0.014056
# charges           0.059455
# smoker_yes        0.079058
# region_northwest -0.006602
# region_southeast  0.013987
# region_southwest -0.004798
# sex_male          1.000000

# %% [markdown]
# ## Многомерная линейная регрессия

# %% [markdown]
# Будем предсказывать значение charges

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

Y = data["charges"].to_numpy(dtype=np.double)
X = data.drop("charges", axis=1).to_numpy(dtype=np.double)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

scaler = StandardScaler();

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# Модель линейной регрессии
# $$\frac{1}{n}\sum\limits_{i=1}^n{(y_i - x_i * w - b) ^ 2} \rightarrow \min\limits_{w, b}$$

# %% [markdown]
# ### Аналитическое решение

# %% [markdown]
# $\overline{X} - (1, X)$ расширенные признаки для байеса
#
# $$(Y - \overline{X}W)^T(Y - \overline{X}W) \rightarrow \min$$
#
# $$Y^TY - 2 Y^T\overline{X}W + W^T\overline{X}^T\overline{X}W \rightarrow \min$$
#
# $$2\overline{X}^T\overline{X}W - 2 \overline{X}^TY = 0$$
#
# $$2\overline{X}^T\overline{X}W = 2 \overline{X}^TY$$
#
# $$W = (2\overline{X}^T\overline{X})^{-1}2\overline{X}^TY$$

# %%
from sklearn.base import RegressorMixin

class AnaliticRegression(RegressorMixin):
    def fit(self, X, Y):
        X = np.column_stack([np.ones(X.shape[0]), X]);
        w = 2 * np.linalg.inv(2 * X.T @ X) @ X.T @ Y
        self.b = w[0]
        self.w = w[1:]

    def predict(self, X):
        return X @ self.w + self.b

# %%
anal = AnaliticRegression();
anal.fit(X_train, Y_train)

print(anal.w, "+", anal.b)

from sklearn.metrics import mean_absolute_error, mean_squared_error

predicted = anal.predict(X_test)

print("mae:", mean_absolute_error(Y_test, predicted))
print("rmse:", mean_squared_error(Y_test, predicted))
# Out:
# [3649.33512945 1924.02859237  629.28757949 9208.30258541 -214.45651175
#  -470.59944911 -511.63739358  -30.77749084] + 13021.298104956048
# mae: 3969.0341267772133
# rmse: 30444091.526395813

# %% [markdown]
# ### Градиентный спуск

# %%
from sklearn.base import RegressorMixin
import numpy as np

class MyLinearRegression(RegressorMixin):
    def __init__(self):
        self.max_steps = 20000;
        self.step = 0.0001;
        self.delta = 0.0001;
        self.alpha = 0.4
        self.regularization = 0;
    def fit(self, X, y):
        self.w = np.random.normal(-5000, 5000, X.shape[1:])
        self.b = 0

        var = np.sum(np.square(X @ self.w + self.b - y)) / len(X)
        i = 0
        prev_grad = 0
        prev_grad_b = 0
        while var > self.delta and i < self.max_steps:
            grad = 2 * (X @ self.w + self.b - y) @ X + 2 * self.regularization * self.w
            grad_b = 2 * (X @ self.w + self.b - y)
            mgrad = prev_grad * self.alpha + grad * (1 - self.alpha)
            mgrad_b = prev_grad_b * self.alpha + grad_b * (1 - self.alpha)
            prev_grad = mgrad
            prev_grad_b = mgrad_b
            self.w -= self.step * mgrad
            self.b -= self.step * mgrad_b[0]
            i += 1
            var = np.sum(np.square(X @ self.w + self.b - y)) / len(X)

        return self

    def predict(self, X):
        return X @ self.w + self.b

# %%
reg = MyLinearRegression()

reg.fit(X_train, Y_train)

print(reg.w, "+", reg.b)

predicted = reg.predict(X_test)

print("mae:", mean_absolute_error(Y_test, predicted))
print("rmse:", mean_squared_error(Y_test, predicted))
# Out:
# [3649.33512945 1924.02859237  629.28757949 9208.30258541 -214.45651175
#  -470.59944911 -511.63739358  -30.77749084] + 11595.434005624986
# mae: 3768.1068216987696
# rmse: 31763737.249400634

# %% [markdown]
# ## Добавление регуляризации

# %% [markdown]
# Модель линейной регрессии
# $$\frac{1}{n}\sum\limits_{i=1}^n{(y_i - x_i * w - b) ^ 2 + \lambda w_i^2} \rightarrow \min\limits_{w, b}$$

# %% [markdown]
# ### Аналитическое решение

# %% [markdown]
# $\overline{X} - (1, X)$ расширенные признаки для байеса
#
# $$(Y - \overline{X}W)^T(Y - \overline{X}W) + \lambda W^TW \rightarrow \min$$
#
# $$2\overline{X}^T\overline{X}W - 2 \overline{X}^TY + 2\lambda W = 0$$
#
# $$(2\overline{X}^T\overline{X} +2 \lambda E) W = 2 \overline{X}^TY$$
#
# $$W = (2\overline{X}^T\overline{X} +2 \lambda E)^{-1}(2 \overline{X}^TY)$$

# %%
from sklearn.base import RegressorMixin

class AnaliticRegression(RegressorMixin):
    def __init__(self):
        self.regularization = 0
    def fit(self, X, Y):
        X = np.column_stack([np.ones(X.shape[0]), X]);
        E = np.eye(X.shape[1]);
        E[0][0] = 0
        w = np.linalg.inv(2 * X.T @ X + 2 * self.regularization * E) @ (2 * X.T @ Y)
        self.b = w[0]
        self.w = w[1:]

    def predict(self, X):
        return X @ self.w + self.b

# %%
anal = AnaliticRegression();
anal.regularization = 1
anal.fit(X_train, Y_train)

print(anal.w, "+", anal.b)

from sklearn.metrics import mean_absolute_error, mean_squared_error

predicted = anal.predict(X_test)

print("mae:", mean_absolute_error(Y_test, predicted))
print("rmse:", mean_squared_error(Y_test, predicted))
# Out:
# [3646.01818704 1921.9736294   629.18997252 9199.25965008 -213.8831276
#  -468.4099675  -510.65218567  -29.98517725] + 13021.298104956046
# mae: 3970.2643122230343
# rmse: 30444628.509259652

# %% [markdown]
# ### Градиентный спуск

# %%
reg = MyLinearRegression()
reg.regularization = 1

reg.fit(X_train, Y_train)

print(reg.w, "+", reg.b)

predicted = reg.predict(X_test)

print("mae:", mean_absolute_error(Y_test, predicted))
print("rmse:", mean_squared_error(Y_test, predicted))
# Out:
# [3646.01818704 1921.9736294   629.18997252 9199.25965008 -213.8831276
#  -468.4099675  -510.65218567  -29.98517725] + 11586.684797349764
# mae: 3767.8863484279264
# rmse: 31786920.06117672

# %% [markdown]
# ## Сравнение моделей

# %%
class MeanRegression(RegressorMixin):
    def fit(self, X, Y):
        self.ans = Y.mean();

    def predict(self, X):
        return self.ans * np.ones(X.shape[0])

# %%
def test_model(model):
    model.fit(X_train, Y_train)
    return mean_squared_error(Y_test, model.predict(X_test))

print("mean:", test_model(MeanRegression()))
anal = AnaliticRegression();
print("Analitic:", test_model(anal))
anal.regularization = 1
print("Analitic + reg:", test_model(anal))
grad = MyLinearRegression()
print("grad:", test_model(grad))
grad.regularization = 1
print("grad + reg:", test_model(grad))
# Out:
# mean: 137709080.74319682
# Analitic: 30444091.526395813
# Analitic + reg: 30444628.509259652
# grad: 31763491.2349701
# grad + reg: 31786773.088079568
